# %% [markdown]
# <a href="https://colab.research.google.com/github/Azizullah0/Setiment_Analysis/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

bv_df = pd.read_csv('/content/drive/MyDrive/ColabFoulder/BV.csv')
kaktos_df = pd.read_csv('/content/drive/MyDrive/ColabFoulder/kaktos.csv')
nr_df = pd.read_csv('/content/drive/MyDrive/ColabFoulder/NR.csv')
peoplemedia_df = pd.read_csv('/content/drive/MyDrive/ColabFoulder/PeopleMedia.csv')
rezafatima_df = pd.read_csv('/content/drive/MyDrive/ColabFoulder/RezaFatima.csv')
clean_data= pd.read_csv('/content/drive/MyDrive/ColabFoulder/Cleaned_Dataset.csv')
telegram_df= pd.read_csv('/content/drive/MyDrive/ColabFoulder/telgram_dateset.csv')
telgram_messageAustrilia_df = pd.read_csv('/content/drive/MyDrive/ColabFoulder/telegram_messagesAustrilia.csv')
# You can then display the head to confirm
display(clean_data.head(9))
# Out:
#                     channel                  date  \
# 0  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-04-07T22:45:55Z
# 1  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-28T16:13:47Z
# 2  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-27T09:57:54Z
# 3  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-25T20:51:16Z
# 4  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-25T20:15:26Z
# 5  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-25T20:10:15Z
# 6  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-24T22:50:34Z
# 7  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-24T19:34:11Z
# 8  UCpQI2HAa3P_WBBEWR3JqnjQ  2025-03-24T18:39:27Z
#
#                                                clean  token_count
# 0                                    ادامه داره یانه            3
# 1               خو‌ای رشخندی چیست سریال رنگ مهتاب کو            7
# 2                                    ای چی رشخندی هس            4
# 3                        اشتباه بزگی ساخت سریال صحنه            5
# 4               میشه فصل بسازین مثلا احمد آلمان رفته            7
# ...

# %%
# Out:
#             channel       chat_id  msg_id                       date  \
# 0  آکادمی زبان دریا  daryaacademy     382  2025-04-20T10:09:09+00:00
# 1  آکادمی زبان دریا  daryaacademy     381  2025-04-20T10:08:42+00:00
# 2  آکادمی زبان دریا  daryaacademy     379  2024-11-04T17:27:21+00:00
# 3  آکادمی زبان دریا  daryaacademy     376  2024-08-17T10:03:19+00:00
# 4  آکادمی زبان دریا  daryaacademy     375  2024-08-17T10:02:36+00:00
# 5  آکادمی زبان دریا  daryaacademy     374  2024-08-17T10:02:14+00:00
# 6  آکادمی زبان دریا  daryaacademy     359  2023-07-16T09:35:06+00:00
# 7  آکادمی زبان دریا  daryaacademy     352  2023-06-16T08:31:31+00:00
# 8  آکادمی زبان دریا  daryaacademy     349  2023-06-10T11:11:27+00:00
#
#                                                 text
# 0                      https://t.me/c/1797434237/754
# 1  معنی این کلمه و چند مورد از بلایای طبیعی رو تو...
# 2  ثبت نام کلاس های حضوری تهران\n\n@academydarya_...
# 3  📚📖🎧\n\n#پادکست\n#sesli_kitap\n\nDürüst hırsız\...
# ...

# %% [markdown]
# ## Summary:
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ### Data Analysis Key Findings
#
# *   All five datasets (`BV.csv`, `kaktos.csv`, `NR.csv`, `PeopleMedia.csv`, and `RezaFatima.csv`) share the same column names: 'channelId', 'videoId', 'author', 'text', and 'publishedAt'.
# *   No overlapping values were found in the 'channelId' or 'videoId' columns when comparing pairs of the datasets, suggesting they contain data from distinct sources.
# *   Missing values were present in 'author' and 'text' columns across `bv_df`, `kaktos_df`, `nr_df`, and `rezafatima_df`.
# *   Duplicate rows were found and removed from `bv_df` (6 duplicates), `kaktos_df` (109 duplicates), `nr_df` (107 duplicates), and `rezafatima_df` (123 duplicates).
# *   `peoplemedia_df` had no missing values or duplicate rows.
#
# ### Insights or Next Steps
#
# *   The datasets appear to be complementary rather than overlapping, potentially allowing for combined analysis if a common key or relationship can be established beyond 'channelId' and 'videoId'.
# *   Further investigation into the content of the 'author' and 'text' columns might reveal patterns or relationships not evident from the IDs alone.
